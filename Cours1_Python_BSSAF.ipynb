# %% [markdown]
# <a href="https://colab.research.google.com/github/Bastien-PZ/Cours_Python_BSSAF/blob/main/Cours1_Python_BSSAF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cours 1 - Découvrir Python

# %%
a = 5
a * 10

# %%
def somme (a,b):
  return a+b;

somme(1,1)
# Out:
# 2

# %%
if a==5:
  print("a est égal à 5")
else:
  print("a n'est pas égal à 5")
# Out:
# a est égal à 5

# %%
def fact(n):
  if n==1:
    return 1
  else:
    return fact(n-1)*n

fact(4)
# Out:
# 24

# %%
a = 1
for i in range(1,11,1):
  a = a*i
  print("factorielle de ", i, "égale", a)
# Out:
# factorielle de  1 égale 1
# factorielle de  2 égale 2
# factorielle de  3 égale 6
# factorielle de  4 égale 24
# factorielle de  5 égale 120
# factorielle de  6 égale 720
# factorielle de  7 égale 5040
# factorielle de  8 égale 40320
# factorielle de  9 égale 362880
# factorielle de  10 égale 3628800

# %%
liste = [1,2]
liste.append(3)
liste
# Out:
# [1, 2, 3]

# %%
liste2 = [i**2 for i in range(10)]
liste2
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
